# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\Jason\Downloads\DataScience\chart.csv")
perc_5k_step = (df.loc[0, 'perc5k'] - df.loc[29, 'perc5k']) / 30
perc_10k_step = (df.loc[0, 'perc10k'] - df.loc[29, 'perc10k']) / 30
hm_perc_step = (df.loc[0, 'perc_hm'] - df.loc[29, 'perc_hm']) / 30
print(perc_5k_step)
df
# Out:
# 0.0008766615942029136
#     8:00 TT Pace    perc5k  5k Pace   perc10k  10k Pace   perc_hm  hm Pace
# 0          250.0  0.971658    257.0  0.926313     270.0  0.888607    281.0
# 1          255.0  0.970751    263.0  0.925634     275.0  0.887746    287.0
# 2          260.0  0.969844    268.0  0.924954     281.0  0.886886    293.0
# 3          265.0  0.968937    273.0  0.924275     287.0  0.886026    299.0
# 4          270.0  0.968030    279.0  0.923595     292.0  0.885166    305.0
# ..           ...       ...      ...       ...       ...       ...      ...
# 66         580.0  0.911803    636.0  0.881473     658.0  0.831843    697.0
# 67         585.0  0.910896    642.0  0.880793     664.0  0.830983    704.0
# 68         590.0  0.909989    648.0  0.880114     670.0  0.830123    711.0
# 69         595.0  0.909082    655.0  0.879435     677.0  0.829263    718.0
# 70         600.0  0.908175    661.0  0.878755     683.0  0.828403    724.0
#
# [71 rows x 7 columns]

# %%
df['8:00 TT Pace'] = (round(df['8:00 TT Pace'])).astype(int)
df['5k Pace'] = (round(df['5k Pace'])).astype(int)
df['10k Pace'] = (round(df['10k Pace'])).astype(int)
df['hm Pace'] = (round(df['hm Pace'])).astype(int)
df['5k Lower'] = (round(df['5k Pace'] * 1.00402898)).astype(int)
df['5k Upper'] = (round(df['5k Pace'] * 1.047778)).astype(int)
df['10k Lower'] = (round(df['10k Pace'] * 1.00402898)).astype(int)
df['10k Upper'] = (round(df['10k Pace'] * 1.047778)).astype(int)
df['hm Lower'] = (round(df['hm Pace'] * 1.00402898)).astype(int)
df['hm Upper'] = (round(df['hm Pace'] * 1.047778)).astype(int)
df['com Lower'] = (round(df['8:00 TT Pace'] / .76)).astype(int)
df['com Upper'] = (round(df['8:00 TT Pace'] / .71)).astype(int)
df['ve Lower'] = (round(df['8:00 TT Pace'] / .7)).astype(int)
df['ve Upper'] = (round(df['8:00 TT Pace'] / .65)).astype(int)
df
# Out:
#     8:00 TT Pace    perc5k  5k Pace   perc10k  10k Pace   perc_hm  hm Pace  \
# 0            250  0.971658      257  0.926313       270  0.888607      281
# 1            255  0.970751      263  0.925634       275  0.887746      287
# 2            260  0.969844      268  0.924954       281  0.886886      293
# 3            265  0.968937      273  0.924275       287  0.886026      299
# 4            270  0.968030      279  0.923595       292  0.885166      305
# ..           ...       ...      ...       ...       ...       ...      ...
# 66           580  0.911803      636  0.881473       658  0.831843      697
# 67           585  0.910896      642  0.880793       664  0.830983      704
# 68           590  0.909989      648  0.880114       670  0.830123      711
# 69           595  0.909082      655  0.879435       677  0.829263      718
# 70           600  0.908175      661  0.878755       683  0.828403      724
#
#     5k Lower  5k Upper  10k Lower  10k Upper  hm Lower  hm Upper  com Lower  \
# 0        258       269        271        283       282       294        329
# 1        264       276        276        288       288       301        336
# 2        269       281        282        294       294       307        342
# 3        274       286        288        301       300       313        349
# 4        280       292        293        306       306       320        355
# ..       ...       ...        ...        ...       ...       ...        ...
# 66       639       666        661        689       700       730        763
# 67       645       673        667        696       707       738        770
# 68       651       679        673        702       714       745        776
# 69       658       686        680        709       721       752        783
# 70       664       693        686        716       727       759        789
#
#     com Upper  ve Lower  ve Upper
# 0         352       357       385
# 1         359       364       392
# 2         366       371       400
# 3         373       379       408
# 4         380       386       415
# ..        ...       ...       ...
# 66        817       829       892
# 67        824       836       900
# 68        831       843       908
# 69        838       850       915
# 70        845       857       923
#
# [71 rows x 17 columns]

# %%
plt.plot(df['8:00 TT Pace']-245, df['5k Upper']-245, color='blue')
plt.plot(df['8:00 TT Pace']-245, df['10k Upper']-245, color='green')
plt.plot(df['8:00 TT Pace']-245, df['hm Upper']-245, color='red')
plt.plot(df['8:00 TT Pace']-245, df['5k Lower']-245, color='blue')
plt.plot(df['8:00 TT Pace']-245, df['10k Lower']-245, color='green')
plt.plot(df['8:00 TT Pace']-245, df['hm Lower']-245, color='red')
plt.plot(df['8:00 TT Pace']-245, df['com Upper']-245, color='purple')
plt.plot(df['8:00 TT Pace']-245, df['com Lower']-245, color='purple')
plt.plot(df['8:00 TT Pace']-245, df['ve Upper']-245, color='orange')
plt.plot(df['8:00 TT Pace']-245, df['ve Lower']-245, color='orange')
plt.fill_between(df['8:00 TT Pace']-245, df['5k Upper']-245, df['5k Lower']-245, color='blue', alpha=0.3)
plt.fill_between(df['8:00 TT Pace']-245, df['10k Upper']-245, df['10k Lower']-245, color='green', alpha=0.3)
plt.fill_between(df['8:00 TT Pace']-245, df['hm Upper']-245, df['hm Lower']-245, color='red', alpha=0.3)
plt.fill_between(df['8:00 TT Pace']-245, df['com Upper']-245, df['com Lower']-245, color='purple', alpha=0.3)
plt.fill_between(df['8:00 TT Pace']-245, df['ve Upper']-245, df['ve Lower']-245, color='orange', alpha=0.3)
plt.show()

# %%
time_df = df
time_df.drop('perc5k', axis=1, inplace=True)
time_df.drop('perc10k', axis=1, inplace=True)
time_df.drop('perc_hm', axis=1, inplace=True)
time_df['8:00 TT Pace'] = df['8:00 TT Pace'].apply(lambda x: f"{x // 60:02}:{x % 60:02}")
time_df['5k Pace'] = df['5k Pace'].apply(lambda x: f"{x // 60:02}:{x % 60:02}")
time_df['10k Pace'] = df['10k Pace'].apply(lambda x: f"{x // 60:02}:{x % 60:02}")
time_df['hm Pace'] = df['hm Pace'].apply(lambda x: f"{x // 60:02}:{x % 60:02}")
time_df['5k Upper'] = df['5k Upper'].apply(lambda x: f"{x // 60:02}:{x % 60:02}")
time_df['5k Lower'] = df['5k Lower'].apply(lambda x: f"{x // 60:02}:{x % 60:02}")
time_df['10k Upper'] = df['10k Upper'].apply(lambda x: f"{x // 60:02}:{x % 60:02}")
time_df['10k Lower'] = df['10k Lower'].apply(lambda x: f"{x // 60:02}:{x % 60:02}")
time_df['hm Upper'] = df['hm Upper'].apply(lambda x: f"{x // 60:02}:{x % 60:02}")
time_df['hm Lower'] = df['hm Lower'].apply(lambda x: f"{x // 60:02}:{x % 60:02}")
time_df['com Upper'] = df['com Upper'].apply(lambda x: f"{x // 60:02}:{x % 60:02}")
time_df['com Lower'] = df['com Lower'].apply(lambda x: f"{x // 60:02}:{x % 60:02}")
time_df['ve Upper'] = df['ve Upper'].apply(lambda x: f"{x // 60:02}:{x % 60:02}")
time_df['ve Lower'] = df['ve Lower'].apply(lambda x: f"{x // 60:02}:{x % 60:02}")
time_df
# Out:
#    8:00 TT Pace 5k Pace 10k Pace hm Pace 5k Lower 5k Upper 10k Lower  \
# 0         04:10   04:17    04:30   04:41    04:18    04:29     04:31
# 1         04:15   04:23    04:35   04:47    04:24    04:36     04:36
# 2         04:20   04:28    04:41   04:53    04:29    04:41     04:42
# 3         04:25   04:33    04:47   04:59    04:34    04:46     04:48
# 4         04:30   04:39    04:52   05:05    04:40    04:52     04:53
# ..          ...     ...      ...     ...      ...      ...       ...
# 66        09:40   10:36    10:58   11:37    10:39    11:06     11:01
# 67        09:45   10:42    11:04   11:44    10:45    11:13     11:07
# 68        09:50   10:48    11:10   11:51    10:51    11:19     11:13
# 69        09:55   10:55    11:17   11:58    10:58    11:26     11:20
# 70        10:00   11:01    11:23   12:04    11:04    11:33     11:26
#
#    10k Upper hm Lower hm Upper com Lower com Upper ve Lower ve Upper
# 0      04:43    04:42    04:54     05:29     05:52    05:57    06:25
# 1      04:48    04:48    05:01     05:36     05:59    06:04    06:32
# 2      04:54    04:54    05:07     05:42     06:06    06:11    06:40
# 3      05:01    05:00    05:13     05:49     06:13    06:19    06:48
# 4      05:06    05:06    05:20     05:55     06:20    06:26    06:55
# ..       ...      ...      ...       ...       ...      ...      ...
# 66     11:29    11:40    12:10     12:43     13:37    13:49    14:52
# 67     11:36    11:47    12:18     12:50     13:44    13:56    15:00
# 68     11:42    11:54    12:25     12:56     13:51    14:03    15:08
# 69     11:49    12:01    12:32     13:03     13:58    14:10    15:15
# 70     11:56    12:07    12:39     13:09     14:05    14:17    15:23
#
# [71 rows x 14 columns]

# %%
final_df = pd.DataFrame()
final_df['8:00 TT Pace'] = time_df['8:00 TT Pace'].copy()
final_df['5k Pace Range'] = time_df['5k Lower'].astype(str) + " - " + time_df['5k Upper'].astype(str)
final_df['10k Pace Range'] = time_df['10k Lower'].astype(str) + " - " + time_df['10k Upper'].astype(str)
final_df['Half Marathon Pace Range'] = time_df['hm Lower'].astype(str) + " - " + time_df['hm Upper'].astype(str)
final_df['Comfortable Pace Range'] = time_df['com Lower'].astype(str) + " - " + time_df['com Upper'].astype(str)
final_df['Very Easy Pace Range'] = time_df['ve Lower'].astype(str) + " - " + time_df['ve Upper'].astype(str)
final_df
# Out:
#    8:00 TT Pace  5k Pace Range 10k Pace Range Half Marathon Pace Range  \
# 0         04:10  04:18 - 04:29  04:31 - 04:43            04:42 - 04:54
# 1         04:15  04:24 - 04:36  04:36 - 04:48            04:48 - 05:01
# 2         04:20  04:29 - 04:41  04:42 - 04:54            04:54 - 05:07
# 3         04:25  04:34 - 04:46  04:48 - 05:01            05:00 - 05:13
# 4         04:30  04:40 - 04:52  04:53 - 05:06            05:06 - 05:20
# ..          ...            ...            ...                      ...
# 66        09:40  10:39 - 11:06  11:01 - 11:29            11:40 - 12:10
# 67        09:45  10:45 - 11:13  11:07 - 11:36            11:47 - 12:18
# 68        09:50  10:51 - 11:19  11:13 - 11:42            11:54 - 12:25
# 69        09:55  10:58 - 11:26  11:20 - 11:49            12:01 - 12:32
# 70        10:00  11:04 - 11:33  11:26 - 11:56            12:07 - 12:39
#
#    Comfortable Pace Range Very Easy Pace Range
# 0           05:29 - 05:52        05:57 - 06:25
# 1           05:36 - 05:59        06:04 - 06:32
# 2           05:42 - 06:06        06:11 - 06:40
# 3           05:49 - 06:13        06:19 - 06:48
# 4           05:55 - 06:20        06:26 - 06:55
# ..                    ...                  ...
# 66          12:43 - 13:37        13:49 - 14:52
# 67          12:50 - 13:44        13:56 - 15:00
# 68          12:56 - 13:51        14:03 - 15:08
# 69          13:03 - 13:58        14:10 - 15:15
# 70          13:09 - 14:05        14:17 - 15:23
#
# [71 rows x 6 columns]

# %%
final_df.to_csv(r"C:\Users\Jason\Downloads\Bowers_Pace_Chart.csv", index=False)
